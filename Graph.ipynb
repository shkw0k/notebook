# %% [markdown]
# #How to show a graph

# %%
import matplotlib.pyplot as plt
import os.path as op
import networkx as nx
import os

# %%
graph = nx.Graph()
os.chdir("/Users/shkwok/magiqWS3/magiq/guiUtils")
topName = "."
graph.add_node(topName)
for f in os.walk(topName):
    currName, dirNames, fileNames = f
    for dn in dirNames:
        longName = currName + "/" + dn
        nn = graph.add_node(longName)
        graph.add_edge(currName, longName)
    """
    for fn in fileNames:
        longName = currName + "/" + fn
        graph.add_node(longName)
        graph.add_edge(currName, longName)
    """

# %%
plt.figure(figsize=(14, 14))
ax = plt.subplot(111)
nx.draw(graph, ax=ax)
